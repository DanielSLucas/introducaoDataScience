# %%
import json
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson import NaturalLanguageUnderstandingV1 
from ibm_watson.natural_language_understanding_v1 import Features, ConceptsOptions, RelationsOptions, EmotionOptions, EntitiesOptions, SemanticRolesOptions, SentimentOptions

# %%
authenticator = IAMAuthenticator('a8DKm5jxiiKJ3XgvdKhZqR51atAO5pOKVqpOgLDoEmco')
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2018-12-19',
    authenticator=authenticator
)

natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/72994a03-3e63-4174-9b35-5aaff84317bd')

# %%
response = natural_language_understanding.analyze(
  text='Who is the president of Brazil?',
  features=Features(
    concepts=ConceptsOptions(),
    emotion=EmotionOptions(),
    entities=EntitiesOptions(),
    sentiment=SentimentOptions(),
    ))
print(response)
# Out:
# {
#     "result": {
#         "usage": {
#             "text_units": 1,
#             "text_characters": 31,
#             "features": 4
#         },
#         "sentiment": {
#             "document": {
#                 "score": 0,
#                 "label": "neutral"
#             }
#         },
#         "language": "en",
#         "entities": [
#             {
#                 "type": "JobTitle",
#                 "text": "president",
#                 "relevance": 0.33,
#                 "count": 1
#             },
#             {
#                 "type": "Location",
#                 "text": "Brazil",
#                 "relevance": 0.33,
#                 "disambiguation": {
#                     "subtype": [
#                         "GovernmentalJurisdiction",
#                         "CompanyShareholder",
#                         "Country"
#                     ],
#                     "name": "Brazil",
#                     "dbpedia_resource": "http://dbpedia.org/resource/Brazil"
#                 },
#                 "count": 1
#             }
#         ],
#         "emotion": {
#             "document": {
#                 "emotion": {
#                     "sadness": 0.117418,
#                     "joy": 0.151672,
#                     "fear": 0.047087,
#                     "disgust": 0.198362,
#                     "anger": 0.149442
#                 }
#             }
#         },
#         "concepts": [
#             {
#                 "text": "President",
#                 "relevance": 0.886784,
#                 "dbpedia_resource": "http://dbpedia.org/resource/President"
#             },
#             {
#                 "text": "President of the United States",
#                 "relevance": 0.862208,
#                 "dbpedia_resource": "http://dbpedia.org/resource/President_of_the_United_States"
#             },
#             {
#                 "text": "Politics of Brazil",
#                 "relevance": 0.845824,
#                 "dbpedia_resource": "http://dbpedia.org/resource/Politics_of_Brazil"
#             }
#         ]
#     },
#     "headers": {
#         "_store": {
#             "x-powered-by": [
#                 "x-powered-by",
#                 "Express"
#             ],
#             "server": [
#                 "Server",
#                 "watson-gateway"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "1367"
#             ],
#             "content-type": [
#                 "Content-Type",
#                 "application/json; charset=utf-8"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "9c456993-bef7-4eeb-881e-273dc86cd78d, 9c456993-bef7-4eeb-881e-273dc86cd78d"
#             ],
#             "content-security-policy": [
#                 "Content-Security-Policy",
#                 "default-src 'none'"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-frame-options": [
#                 "x-frame-options",
#                 "DENY"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1; mode=block"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-request-id": [
#                 "x-request-id",
#                 "9c456993-bef7-4eeb-881e-273dc86cd78d"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "9c456993-bef7-4eeb-881e-273dc86cd78d"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "134"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "208"
#             ],
#             "date": [
#                 "Date",
#                 "Thu, 10 Jun 2021 14:52:14 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %%
response = natural_language_understanding.analyze(
  text='Steve Jobs is the founder of Apple',
  features=Features(
    entities=EntitiesOptions(),
    semantic_roles=SemanticRolesOptions(),
    ))

print(response)
# Out:
# {
#     "result": {
#         "usage": {
#             "text_units": 1,
#             "text_characters": 34,
#             "features": 2
#         },
#         "semantic_roles": [
#             {
#                 "subject": {
#                     "text": "Steve Jobs"
#                 },
#                 "sentence": "Steve Jobs is the founder of Apple",
#                 "object": {
#                     "text": "the founder of Apple"
#                 },
#                 "action": {
#                     "verb": {
#                         "text": "be",
#                         "tense": "present"
#                     },
#                     "text": "is",
#                     "normalized": "be"
#                 }
#             }
#         ],
#         "language": "en",
#         "entities": [
#             {
#                 "type": "Person",
#                 "text": "Steve Jobs",
#                 "relevance": 0.33,
#                 "disambiguation": {
#                     "subtype": [
#                         "BoardMember",
#                         "CompanyFounder",
#                         "ComputerDesigner",
#                         "FilmProducer"
#                     ],
#                     "name": "Steve Jobs",
#                     "dbpedia_resource": "http://dbpedia.org/resource/Steve_Jobs"
#                 },
#                 "count": 1
#             },
#             {
#                 "type": "JobTitle",
#                 "text": "founder",
#                 "relevance": 0.33,
#                 "count": 1
#             },
#             {
#                 "type": "Company",
#                 "text": "Apple",
#                 "relevance": 0.33,
#                 "count": 1
#             }
#         ]
#     },
#     "headers": {
#         "_store": {
#             "x-powered-by": [
#                 "x-powered-by",
#                 "Express"
#             ],
#             "server": [
#                 "Server",
#                 "watson-gateway"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "1091"
#             ],
#             "content-type": [
#                 "Content-Type",
#                 "application/json; charset=utf-8"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "a705b8c0-b864-4593-bb3d-df79b0da981d, a705b8c0-b864-4593-bb3d-df79b0da981d"
#             ],
#             "content-security-policy": [
#                 "Content-Security-Policy",
#                 "default-src 'none'"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-frame-options": [
#                 "x-frame-options",
#                 "DENY"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1; mode=block"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-request-id": [
#                 "x-request-id",
#                 "a705b8c0-b864-4593-bb3d-df79b0da981d"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "a705b8c0-b864-4593-bb3d-df79b0da981d"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "133"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "133"
#             ],
#             "date": [
#                 "Date",
#                 "Thu, 10 Jun 2021 14:52:44 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ]
#         }
#     },
#     "status_code": 200
# }

# %%
response = natural_language_understanding.analyze(
  text='Na FIAP, os alunos são muito dedicados.',
  features=Features(
    relations=RelationsOptions(),
    concepts=ConceptsOptions(),
    emotion=EmotionOptions(),
    entities=EntitiesOptions(),
    semantic_roles=SemanticRolesOptions(),
    sentiment=SentimentOptions(),
    ))

print(response)
# Out:
# {
#     "result": {
#         "usage": {
#             "text_units": 1,
#             "text_characters": 39,
#             "features": 4
#         },
#         "sentiment": {
#             "document": {
#                 "score": 0.75298,
#                 "label": "positive"
#             }
#         },
#         "relations": [],
#         "language": "pt",
#         "entities": [
#             {
#                 "type": "Organization",
#                 "text": "FIAP",
#                 "relevance": 0.978348,
#                 "count": 1,
#                 "confidence": 0.879578
#             }
#         ],
#         "concepts": [],
#         "warnings": [
#             "emotion: unsupported text language: pt",
#             "semantic_roles: unsupported text language: pt"
#         ]
#     },
#     "headers": {
#         "_store": {
#             "x-powered-by": [
#                 "x-powered-by",
#                 "Express"
#             ],
#             "server": [
#                 "Server",
#                 "watson-gateway"
#             ],
#             "content-length": [
#                 "Content-Length",
#                 "519"
#             ],
#             "content-type": [
#                 "Content-Type",
#                 "application/json; charset=utf-8"
#             ],
#             "cache-control": [
#                 "Cache-Control",
#                 "no-cache, no-store"
#             ],
#             "x-dp-watson-tran-id": [
#                 "x-dp-watson-tran-id",
#                 "321dacb2-84fb-4de0-b404-146b7eae2362, 321dacb2-84fb-4de0-b404-146b7eae2362"
#             ],
#             "content-security-policy": [
#                 "Content-Security-Policy",
#                 "default-src 'none'"
#             ],
#             "pragma": [
#                 "Pragma",
#                 "no-cache"
#             ],
#             "x-content-type-options": [
#                 "x-content-type-options",
#                 "nosniff"
#             ],
#             "x-frame-options": [
#                 "x-frame-options",
#                 "DENY"
#             ],
#             "x-xss-protection": [
#                 "x-xss-protection",
#                 "1; mode=block"
#             ],
#             "strict-transport-security": [
#                 "strict-transport-security",
#                 "max-age=31536000; includeSubDomains;"
#             ],
#             "x-request-id": [
#                 "x-request-id",
#                 "321dacb2-84fb-4de0-b404-146b7eae2362"
#             ],
#             "x-global-transaction-id": [
#                 "x-global-transaction-id",
#                 "321dacb2-84fb-4de0-b404-146b7eae2362"
#             ],
#             "x-edgeconnect-midmile-rtt": [
#                 "X-EdgeConnect-MidMile-RTT",
#                 "133"
#             ],
#             "x-edgeconnect-origin-mex-latency": [
#                 "X-EdgeConnect-Origin-MEX-Latency",
#                 "243"
#             ],
#             "date": [
#                 "Date",
#                 "Thu, 10 Jun 2021 14:56:11 GMT"
#             ],
#             "connection": [
#                 "Connection",
#                 "keep-alive"
#             ]
#         }
#     },
#     "status_code": 200
# }
